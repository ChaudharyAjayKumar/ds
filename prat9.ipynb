# %%
# a) Binary Tree Traversal
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BinaryTree:
    def __init__(self):
        self.root = None

    def insert(self, value):
        if self.root is None:
            self.root = Node(value)
        else:
            self._insert_rec(self.root, value)

    def _insert_rec(self, current_node, value):
        if value < current_node.value:
            if current_node.left is None:
                current_node.left = Node(value)
            else:
                self._insert_rec(current_node.left, value)
        else:
            if current_node.right is None:
                current_node.right = Node(value)
            else:
                self._insert_rec(current_node.right, value)

    def in_order(self, node):
        if node:
            self.in_order(node.left)
            print(node.value, end=' ')
            self.in_order(node.right)

    def pre_order(self, node):
        if node:
            print(node.value, end=' ')
            self.pre_order(node.left)
            self.pre_order(node.right)

    def post_order(self, node):
        if node:
            self.post_order(node.left)
            self.post_order(node.right)
            print(node.value, end=' ')

# Example usage
if __name__ == "__main__":
    tree = BinaryTree()
    values = [7, 4, 9, 1, 6, 8, 10]

    for val in values:
        tree.insert(val)

    print("In-order traversal:")
    tree.in_order(tree.root)  # Output: 1 4 6 7 8 9 10
    print("\nPre-order traversal:")
    tree.pre_order(tree.root)  # Output: 7 4 1 6 9 8 10
    print("\nPost-order traversal:")
    tree.post_order(tree.root)  # Output: 1 6 4 8 10 9 7
# Out:
# In-order traversal:
# 1 4 6 7 8 9 10
# Pre-order traversal:
# 7 4 1 6 9 8 10
# Post-order traversal:
# 1 6 4 8 10 9 7
